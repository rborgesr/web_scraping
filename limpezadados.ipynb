# %%
import re 
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
# carrega os arquivos
df = pd.read_csv('dados/Processamento/animeInfoCombination.csv')

# %%
# aumenta o numero de colunas que podemos visualizar aqui no navegador
pd.set_option("display.max_columns", 97)

# %%
#visualiza amostra de dados
df.head()
# Out:
#                                           name  \
# 0                      Violet Evergarden Movie
# 1  Shingeki no Kyojin: The Final Season Part 2
# 2                           Kingdom 4th Season
# 3                                 Vinland Saga
# 4           Code Geass: Hangyaku no Lelouch R2
#
#                                            producers  ranking  votersCount  \
# 0  ['Aniplex', 'Dentsu', 'Shogakukan-ShueishaProd...        1       455691
# 1  ['Aniplex', 'SquareEnix', 'MainichiBroadcastin...        2      2139768
# 2  ['FrontierWorks', 'MediaFactory', 'KadokawaSho...        3      1412369
# 3                   ['TVTokyo', 'Aniplex', 'Dentsu']        4       253894
# 4  ['ProductionI.G', 'Dentsu', 'MainichiBroadcast...        5      1609418
#
#    score  popularity  members  favorite  episodes animeType premiredDate  \
# 0   9.35         235   811317     47477      28.0        TV     Fall2023
# 1   9.09           3  3378519    227339      64.0        TV   Spring2009
# 2   9.07          14  2587838    190464      24.0        TV   Spring2011
# 3   9.06         341   637587     16762      51.0        TV   Spring2015
# 4   9.05          21  2309721     59152      10.0        TV   Spring2019
#
#     animeSource                                             genres  \
# 0         Manga  ['AdventureAdventure', ' DramaDrama', ' Fantas...
# 1         Manga  ['ActionAction', ' AdventureAdventure', ' Dram...
# 2  Visual novel  ['DramaDrama', ' Sci-FiSci-Fi', ' SuspenseSusp...
# 3         Manga  ['ActionAction', ' ComedyComedy', ' Sci-FiSci-...
# 4         Manga  ['ActionAction', ' DramaDrama', ' SuspenseSusp...
#
#                studios                            licenses  \
# 0             Madhouse                                 NaN
# 1                Bones  ['Funimation', 'AniplexofAmerica']
# 2             WhiteFox                      ['Funimation']
# 3  BandaiNamcoPictures       ['Funimation', 'Crunchyroll']
# 4            WitStudio                      ['Funimation']
#
#                       rating  \
# 0       PG-13-Teens13orolder
# 1  R-17+(violence&profanity)
# 2       PG-13-Teens13orolder
# 3       PG-13-Teens13orolder
# 4  R-17+(violence&profanity)
#
#                            voiceActorNameandlanguage  \
# 0  [['Ichinose,Kana', 'Japanese'], ['Harris,Jill'...
# 1  [['Kugimiya,Rie', 'Japanese'], ['Ponticelli,Be...
# 2  [['Seki,Tomokazu', 'Japanese'], ['Rinehart,Tys...
# 3  [['Kugimiya,Rie', 'Japanese'], ['Ishii,Kouji',...
# 4  [['Ishikawa,Yui', 'Japanese'], ['Perino,Elena'...
#
#                               staffNameandOccupation
# 0  [['Aoki,Haruka', 'Producer'], ['Fukushi,Yuuich...
# 1  [['Cook,Justin', 'Producer'], ['Maruyama,Hiroo...
# 2  [['Cook,Justin', 'Producer'], ['Danno,Yoshito'...
# 3  [['Miyawaki,Chizuru', 'Director,Storyboard,Key...
# 4  [['Cook,Justin', 'Producer'], ['Kinoshita,Tets...

# %%
df["producers"]
# Out:
# 0      ['Aniplex', 'Dentsu', 'Shogakukan-ShueishaProd...
# 1      ['Aniplex', 'SquareEnix', 'MainichiBroadcastin...
# 2      ['FrontierWorks', 'MediaFactory', 'KadokawaSho...
# 3                       ['TVTokyo', 'Aniplex', 'Dentsu']
# 4      ['ProductionI.G', 'Dentsu', 'MainichiBroadcast...
#                              ...
# 495    ['BandaiVisual', 'Dentsu', 'VictorEntertainmen...
# 496                   ['BandaiVisual', 'NihonAdSystems']
# 497                       ['ProductionI.G', 'flyingDOG']
# 498                                      ['AkitaShoten']
# 499                      ['TOHO', 'RobotCommunications']
# Name: producers, Length: 500, dtype: object

# %%
def remove_quote(word):
    return word.replace("'","")

# %%
def remove_openBracket(word):
    return word.replace("[","")

# %%
def remove_closeBracket(word):
    return word.replace("]","")

# %%
def remove_commaWithSemicolon(word):
    return word.replace(",",";")

# %%
def remove_space(word):
    return word.replace(" ","")

# %%
# Aplica as funções para formatar os nomes dos producers
df['producers'] = remove_quote(df['producers'].str)
df['producers'] = remove_openBracket(df['producers'].str)
df['producers'] = remove_closeBracket(df['producers'].str)
df['producers'] = remove_commaWithSemicolon(df['producers'].str)
df['producers'] = remove_space(df['producers'].str)

# %%
df["producers"]
# Out:
# 0      Aniplex;Dentsu;Shogakukan-ShueishaProductions;...
# 1      Aniplex;SquareEnix;MainichiBroadcastingSystem;...
# 2      FrontierWorks;MediaFactory;KadokawaShoten;Movi...
# 3                                 TVTokyo;Aniplex;Dentsu
# 4      ProductionI.G;Dentsu;MainichiBroadcastingSyste...
#                              ...
# 495    BandaiVisual;Dentsu;VictorEntertainment;Nippon...
# 496                          BandaiVisual;NihonAdSystems
# 497                              ProductionI.G;flyingDOG
# 498                                          AkitaShoten
# 499                             TOHO;RobotCommunications
# Name: producers, Length: 500, dtype: object

# %%
# Aplica as funções para formatar os nomes dos genres
df['genres'] = remove_quote(df['genres'].str)
df['genres'] = remove_openBracket(df['genres'].str)
df['genres'] = remove_closeBracket(df['genres'].str)
df['genres'] = remove_commaWithSemicolon(df['genres'].str)
df['genres'] = remove_space(df['genres'].str)

# %%
df["genres"]
# Out:
# 0           AdventureAdventure;DramaDrama;FantasyFantasy
# 1      ActionAction;AdventureAdventure;DramaDrama;Fan...
# 2               DramaDrama;Sci-FiSci-Fi;SuspenseSuspense
# 3                 ActionAction;ComedyComedy;Sci-FiSci-Fi
# 4               ActionAction;DramaDrama;SuspenseSuspense
#                              ...
# 495    ActionAction;AwardWinningAwardWinning;MysteryM...
# 496                                                  NaN
# 497                            DramaDrama;FantasyFantasy
# 498    ActionAction;AdventureAdventure;SupernaturalSu...
# 499                            ComedyComedy;Sci-FiSci-Fi
# Name: genres, Length: 500, dtype: object

# %%
# Aplica as funções para formatar os nomes dos licenses
df['licenses'] = remove_quote(df['licenses'].str)
df['licenses'] = remove_openBracket(df['licenses'].str)
df['licenses'] = remove_closeBracket(df['licenses'].str)
df['licenses'] = remove_commaWithSemicolon(df['licenses'].str)
df['licenses'] = remove_space(df['licenses'].str)

# %%
#listar
df.head()
# Out:
#                                           name  \
# 0                      Violet Evergarden Movie
# 1  Shingeki no Kyojin: The Final Season Part 2
# 2                           Kingdom 4th Season
# 3                                 Vinland Saga
# 4           Code Geass: Hangyaku no Lelouch R2
#
#                                            producers  ranking  votersCount  \
# 0  Aniplex;Dentsu;Shogakukan-ShueishaProductions;...        1       455691
# 1  Aniplex;SquareEnix;MainichiBroadcastingSystem;...        2      2139768
# 2  FrontierWorks;MediaFactory;KadokawaShoten;Movi...        3      1412369
# 3                             TVTokyo;Aniplex;Dentsu        4       253894
# 4  ProductionI.G;Dentsu;MainichiBroadcastingSyste...        5      1609418
#
#    score  popularity  members  favorite  episodes animeType premiredDate  \
# 0   9.35         235   811317     47477      28.0        TV     Fall2023
# 1   9.09           3  3378519    227339      64.0        TV   Spring2009
# 2   9.07          14  2587838    190464      24.0        TV   Spring2011
# 3   9.06         341   637587     16762      51.0        TV   Spring2015
# 4   9.05          21  2309721     59152      10.0        TV   Spring2019
#
#     animeSource                                             genres  \
# 0         Manga       AdventureAdventure;DramaDrama;FantasyFantasy
# 1         Manga  ActionAction;AdventureAdventure;DramaDrama;Fan...
# 2  Visual novel           DramaDrama;Sci-FiSci-Fi;SuspenseSuspense
# 3         Manga             ActionAction;ComedyComedy;Sci-FiSci-Fi
# 4         Manga           ActionAction;DramaDrama;SuspenseSuspense
#
#                studios                     licenses  \
# 0             Madhouse                          NaN
# 1                Bones  Funimation;AniplexofAmerica
# 2             WhiteFox                   Funimation
# 3  BandaiNamcoPictures       Funimation;Crunchyroll
# 4            WitStudio                   Funimation
#
#                       rating  \
# 0       PG-13-Teens13orolder
# 1  R-17+(violence&profanity)
# 2       PG-13-Teens13orolder
# 3       PG-13-Teens13orolder
# 4  R-17+(violence&profanity)
#
#                            voiceActorNameandlanguage  \
# 0  [['Ichinose,Kana', 'Japanese'], ['Harris,Jill'...
# 1  [['Kugimiya,Rie', 'Japanese'], ['Ponticelli,Be...
# 2  [['Seki,Tomokazu', 'Japanese'], ['Rinehart,Tys...
# 3  [['Kugimiya,Rie', 'Japanese'], ['Ishii,Kouji',...
# 4  [['Ishikawa,Yui', 'Japanese'], ['Perino,Elena'...
#
#                               staffNameandOccupation
# 0  [['Aoki,Haruka', 'Producer'], ['Fukushi,Yuuich...
# 1  [['Cook,Justin', 'Producer'], ['Maruyama,Hiroo...
# 2  [['Cook,Justin', 'Producer'], ['Danno,Yoshito'...
# 3  [['Miyawaki,Chizuru', 'Director,Storyboard,Key...
# 4  [['Cook,Justin', 'Producer'], ['Kinoshita,Tets...

# %%
#Criar novo dataframe a partir do split da lista ... pra nao mexer nesse anterior cópia
newdf = pd.DataFrame(df["genres"].str.split(';'))

# %%
#listar
newdf.head()
# Out:
#                                               genres
# 0   [AdventureAdventure, DramaDrama, FantasyFantasy]
# 1  [ActionAction, AdventureAdventure, DramaDrama,...
# 2       [DramaDrama, Sci-FiSci-Fi, SuspenseSuspense]
# 3         [ActionAction, ComedyComedy, Sci-FiSci-Fi]
# 4       [ActionAction, DramaDrama, SuspenseSuspense]

# %%
#obtendo a lista de generos unicos para qure possamos substitui-los todos mais tarde
unique_values = []
for genres in newdf["genres"]:
    if type(genres) != float:
        for genre in genres:
            if genre not in unique_values:
                unique_values.append(genre)

# %%
#todos os generos unicos
unique_values
# Out:
# ['AdventureAdventure',
#  'DramaDrama',
#  'FantasyFantasy',
#  'ActionAction',
#  'Sci-FiSci-Fi',
#  'SuspenseSuspense',
#  'ComedyComedy',
#  'RomanceRomance',
#  'MysteryMystery',
#  'SupernaturalSupernatural',
#  'AwardWinningAwardWinning',
#  'SportsSports',
#  'SliceofLifeSliceofLife',
#  'EcchiEcchi',
#  'GourmetGourmet',
#  'HorrorHorror',
#  'AvantGardeAvantGarde',
#  'BoysLoveBoysLove']

# %%
# Exemplo de DataFrame
newdf = pd.DataFrame({
    'genres': [
        ["ActionAction", "FantasyFantasy"],
        ["ActionAction", "DramaDrama", "FantasyFantasy"],
        ["DramaDrama", "Sci-Fi", "SuspenseSuspense"],
        ["ActionAction", "ComedyComedy", "Sci-FiSci-Fi"],
        ["ActionAction", "DramaDrama", "SuspenseSuspense"]
    ]
})

# Passando por todos os dados e, em seguida, mudando seus gêneros
for index, genres in enumerate(newdf["genres"]):
    new_genre = []
    if type(genres) != float:
        for genre in genres:
            if genre == "ActionAction":
                new_genre.append("Action")
            elif genre == "AdventureAdventure":
                new_genre.append("Adventure")
            elif genre == "ComedyComedy":
                new_genre.append("Comedy")
            elif genre == "DramaDrama":
                new_genre.append("Drama")
            elif genre == "FantasyFantasy":
                new_genre.append("Fantasy")
            elif genre == "Sci-FiSci-Fi":
                new_genre.append("Sci-Fi")
            elif genre == "MysteryMystery":
                new_genre.append("Mystery")
            elif genre == "SuspenseSuspense":
                new_genre.append("Suspense")
            elif genre == "RomanceRomance":
                new_genre.append("Romance")
            elif genre == "SliceofLifeSliceofLife":
                new_genre.append("Slice_of_Life")
            elif genre == "SupernaturalSupernatural":
                new_genre.append("Supernatural")
            elif genre == "SportsSports":
                new_genre.append("Sports")
            elif genre == "HorrorHorror":
                new_genre.append("Horror")
            elif genre == "EcchiEcchi":
                new_genre.append("Ecchi")
            elif genre == "AvantGardeAvantGarde":
                new_genre.append("Avant_garde")
            elif genre == "BoysLoveBoysLove":
                new_genre.append("Boys_Love")
            elif genre == "GourmetGourmet":
                new_genre.append("Gourmet")
            elif genre == "GirlsLoveGirlsLove":
                new_genre.append("Girls_Love")
            elif genre == "WorkLifeWorkLife":
                new_genre.append("Work_Life") 

        newdf.at[index, "genres"] = ";".join(new_genre)

# Imprimir DataFrame para verificação
#print(newdf)

# %%
newdf.head()
# Out:
#                   genres
# 0         Action;Fantasy
# 1   Action;Drama;Fantasy
# 2         Drama;Suspense
# 3   Action;Comedy;Sci-Fi
# 4  Action;Drama;Suspense

# %%
#substituindo as informações de gêneros pelo dados limpos
df["genres"] = newdf["genres"]

# %%
df.head()
# Out:
#                                           name  \
# 0                      Violet Evergarden Movie
# 1  Shingeki no Kyojin: The Final Season Part 2
# 2                           Kingdom 4th Season
# 3                                 Vinland Saga
# 4           Code Geass: Hangyaku no Lelouch R2
#
#                                            producers  ranking  votersCount  \
# 0  Aniplex;Dentsu;Shogakukan-ShueishaProductions;...        1       455691
# 1  Aniplex;SquareEnix;MainichiBroadcastingSystem;...        2      2139768
# 2  FrontierWorks;MediaFactory;KadokawaShoten;Movi...        3      1412369
# 3                             TVTokyo;Aniplex;Dentsu        4       253894
# 4  ProductionI.G;Dentsu;MainichiBroadcastingSyste...        5      1609418
#
#    score  popularity  members  favorite  episodes animeType premiredDate  \
# 0   9.35         235   811317     47477      28.0        TV     Fall2023
# 1   9.09           3  3378519    227339      64.0        TV   Spring2009
# 2   9.07          14  2587838    190464      24.0        TV   Spring2011
# 3   9.06         341   637587     16762      51.0        TV   Spring2015
# 4   9.05          21  2309721     59152      10.0        TV   Spring2019
#
#     animeSource                 genres              studios  \
# 0         Manga         Action;Fantasy             Madhouse
# 1         Manga   Action;Drama;Fantasy                Bones
# 2  Visual novel         Drama;Suspense             WhiteFox
# 3         Manga   Action;Comedy;Sci-Fi  BandaiNamcoPictures
# 4         Manga  Action;Drama;Suspense            WitStudio
#
#                       licenses                     rating  \
# 0                          NaN       PG-13-Teens13orolder
# 1  Funimation;AniplexofAmerica  R-17+(violence&profanity)
# 2                   Funimation       PG-13-Teens13orolder
# 3       Funimation;Crunchyroll       PG-13-Teens13orolder
# 4                   Funimation  R-17+(violence&profanity)
#
#                            voiceActorNameandlanguage  \
# 0  [['Ichinose,Kana', 'Japanese'], ['Harris,Jill'...
# 1  [['Kugimiya,Rie', 'Japanese'], ['Ponticelli,Be...
# 2  [['Seki,Tomokazu', 'Japanese'], ['Rinehart,Tys...
# 3  [['Kugimiya,Rie', 'Japanese'], ['Ishii,Kouji',...
# 4  [['Ishikawa,Yui', 'Japanese'], ['Perino,Elena'...
#
#                               staffNameandOccupation
# 0  [['Aoki,Haruka', 'Producer'], ['Fukushi,Yuuich...
# 1  [['Cook,Justin', 'Producer'], ['Maruyama,Hiroo...
# 2  [['Cook,Justin', 'Producer'], ['Danno,Yoshito'...
# 3  [['Miyawaki,Chizuru', 'Director,Storyboard,Key...
# 4  [['Cook,Justin', 'Producer'], ['Kinoshita,Tets...

# %%
# Criamos um dataframe apenas para voiceActorNameandLanguage pq queremos fazer as mudanças
# e depois acrescenta-las ao dataframe original

newdf = pd.DataFrame(df["voiceActorNameandlanguage"])

# %%
#Removendo [[e]] do final de cada string em voiceActorNameandLanguage
for index, data in enumerate(newdf["voiceActorNameandlanguage"]):
    if type(data) != float:
        newdf["voiceActorNameandlanguage"][index] = newdf["voiceActorNameandlanguage"][index].replace("[[","[")
        newdf["voiceActorNameandlanguage"][index] = newdf["voiceActorNameandlanguage"][index].replace("]]","]")

# %%
# Remove aspas simples e [ de voiceActorNameandLanguage
newdf["voiceActorNameandlanguage"] = remove_quote(newdf["voiceActorNameandlanguage"].str)
newdf["voiceActorNameandlanguage"] = remove_openBracket(newdf["voiceActorNameandlanguage"].str)

# %%
# Remove "], " e então [ e então faz o split dos dados com base em:
# por fim, criar a lista de atores e seus idiomas
for index, data in enumerate(newdf["voiceActorNameandlanguage"]):
    if type(data) != float:
        newdf["voiceActorNameandlanguage"][index] = re.sub(r"], ", ";", newdf["voiceActorNameandlanguage"][index])
        newdf["voiceActorNameandlanguage"][index] = remove_closeBracket(newdf["voiceActorNameandlanguage"][index])
        newdf["voiceActorNameandlanguage"][index] = newdf["voiceActorNameandlanguage"][index].split(";")
        for i, newData in enumerate(newdf["voiceActorNameandlanguage"][index]):
            newdf["voiceActorNameandlanguage"][index][i] = newdf["voiceActorNameandlanguage"][index][i].split(", ")

# %%
#Obtém os idiomas únicos usados em diferentes animes
#Encontramos idiomas únicos para qure possam ser nossas colunas
unique_languages = []
for index, info in enumerate(newdf["voiceActorNameandlanguage"]):
    for data in newdf["voiceActorNameandlanguage"][index]:
        if len(data) > 1:
            if data[1] not in unique_languages:
                unique_languages.append(data[1])

# %%
#Listar idiomas únicos
unique_languages
# Out:
# ['Japanese',
#  'English',
#  'French',
#  'Portuguese(BR)',
#  'Italian',
#  'Spanish',
#  'German',
#  'Hungarian',
#  'Korean',
#  'Mandarin',
#  'Hebrew']

# %%
#Criando um dicionário de lista para que possamos transformá-lo em um dataframe mais tarde
new_dic = dict()
for data in unique_languages:
    new_dic[data] = []

# %%
new_dic
# Out:
# {'Japanese': [],
#  'English': [],
#  'French': [],
#  'Portuguese(BR)': [],
#  'Italian': [],
#  'Spanish': [],
#  'German': [],
#  'Hungarian': [],
#  'Korean': [],
#  'Mandarin': [],
#  'Hebrew': []}

# %%
# Inicializando um dicionário para armazenar os dados
new_dic = {
    "Japanese": [],
    "English": [],
    "French": [],
    "Portuguese(BR)": [],
    "Italian": [],
    "Spanish": [],
    "German": [],
    "Hungarian": [],
    "Korean": [],
    "Mandarin": [],
    "Hebrew": []
}

# Criando um dataframe que irá dividir as vozes dos atores com base em seu idioma
for index, info in enumerate(newdf["voiceActorNameandlanguage"]):
    # Inicializando listas para cada idioma
    Japanese = []
    English = []
    French = []
    PortugueseBR = []
    Italian = []
    Spanish = []
    German = []
    Hungarian = []
    Korean = []
    Mandarin = []
    Hebrew = []

    # Verificando se a informação contém mais de um item
    if len(info) > 1:
        for data in info:
            if data[1] == "Japanese":
                Japanese.append(data[0])
            elif data[1] == "Italian":
                Italian.append(data[0])
            elif data[1] == "Portuguese(BR)":
                PortugueseBR.append(data[0])
            elif data[1] == "German":
                German.append(data[0])
            elif data[1] == "Hungarian":
                Hungarian.append(data[0])
            elif data[1] == "English":
                English.append(data[0])
            elif data[1] == "Korean":
                Korean.append(data[0])
            elif data[1] == "Spanish":
                Spanish.append(data[0])
            elif data[1] == "French":
                French.append(data[0])
            elif data[1] == "Mandarin":
                Mandarin.append(data[0])
            elif data[1] == "Hebrew":
                Hebrew.append(data[0])
    else:
        # Caso não haja dados, adicionar np.nan
        for key in new_dic.keys():
            new_dic[key].append(np.nan)
        continue  # Pular para o próximo loop

    # Adicionando os resultados ao dicionário
    new_dic["Japanese"].append(";".join(Japanese) if Japanese else np.nan)
    new_dic["Italian"].append(";".join(Italian) if Italian else np.nan)
    new_dic["Portuguese(BR)"].append(";".join(PortugueseBR) if PortugueseBR else np.nan)
    new_dic["German"].append(";".join(German) if German else np.nan)
    new_dic["Hungarian"].append(";".join(Hungarian) if Hungarian else np.nan)
    new_dic["English"].append(";".join(English) if English else np.nan)
    new_dic["Korean"].append(";".join(Korean) if Korean else np.nan)
    new_dic["Spanish"].append(";".join(Spanish) if Spanish else np.nan)
    new_dic["French"].append(";".join(French) if French else np.nan)
    new_dic["Mandarin"].append(";".join(Mandarin) if Mandarin else np.nan)
    new_dic["Hebrew"].append(";".join(Hebrew) if Hebrew else np.nan)

# Convertendo o dicionário para um DataFrame
new_df = pd.DataFrame(new_dic)

# %%
#Converte o dicionario em Dataframe
newestdf = pd.DataFrame(new_dic)

# %%
newestdf.head()
# Out:
#                                             Japanese  \
# 0  Ichinose,Kana;Tanezaki,Atsumi;Kobayashi,Chiaki...
# 1  Kugimiya,Rie;Park,Romi;Soumi,Youko;Kugimiya,Ri...
# 2  Seki,Tomokazu;Imai,Asami;Miyano,Mamoru;Hanazaw...
# 3  Kugimiya,Rie;Ishii,Kouji;Sugita,Tomokazu;Tomat...
# 4  Ishikawa,Yui;Inoue,Marina;Kamiya,Hiroshi;Kaji,...
#
#                                              English  \
# 0  Harris,Jill;Rodak,Mallorie;Cruz,JordanDash;Kar...
# 1  Whitehead,Maxey;Truncale,Lily;Mignogna,Vic;Hof...
# 2  Rinehart,Tyson;Nishimura,Trina;Tatum,J.Michael...
# 3  Loewen,Jocelyne;Daingerfield,Michael;Pitre,Sab...
# 4  Nishimura,Trina;Grelle,JessieJames;Mercer,Matt...
#
#                                               French  \
# 0  Thellier,Jehanne;Nonnenmacher,Marie;Lecordier,...
# 1  Pic,Audrey;Boudonnat,Lucille;Pestel,Arthur;Cré...
# 2  Pasquier,Laurent;Cornibert,Sarah;Wilhelm,Marc;...
# 3                                                NaN
# 4  Bienaimé,Nathalie;Niverd,Victor;Méyère,Bruno;B...
#
#                                       Portuguese(BR)  \
# 0  Rosis,MariaClara;Souza,Jacque;Miagusuku,Lucas;...
# 1  Andreatto,Rodrigo;Santana,Marina;Campos,Marcel...
# 2  Casemiro,Bruno;Cunha,Maitê;Rinaldi,André;Lua,B...
# 3                                                NaN
# 4  Stefane,Mayara;Volpato,Pedro;Sangregório,Bruno...
#
#                                              Italian  \
# 0  Marteddu,Agnese;Felli,Martina;Marteddu,Tito;Ru...
# 1  Ponticelli,Benedetta;Novara,Renato;Scianca,Pat...
# 2  Vivio,Paolo;Paolelli,Rachele;Chevalier,Davide;...
# 3  Granato,Jolanda;Fazio,Davide;Viola,Federico;Ma...
# 4  Perino,Elena;Bolognesi,Gaia;Raffaeli,Daniele;C...
#
#                                              Spanish  \
# 0  Estrada,Azucena;Ugalde,Erika;MartínezTorizes,E...
# 1  Torres,Jhonny;Vieira,JoséManuel;Escobar,Ricard...
# 2  Fernández,Iván;Vázquez,Camila;Naro,Jordi;Ramír...
# 3                                                NaN
# 4  Molina,Graciela;Lobo,Ana;Gómez,Marc;deAlba,Héc...
#
#                                               German  \
# 0  Fölster,Linda;Casper,Julia;Schächter,Janek;Vuc...
# 1  Gerick,Wanja;Turba,David;Häcke,Maximiliane;Mai...
# 2  Wirthgen,Jesco;Bäcker,Manuela;Gavrilis,Marios;...
# 3                                                NaN
# 4  Halm,Florian;Felder,Max;Gavrilis,Marios;Schwar...
#
#                                            Hungarian  \
# 0                                                NaN
# 1  Baráth,István;Szabó,Máté;Faragó,András;Varga,R...
# 2  Seszták,Szabolcs;NemesTakách,Kata;Juhász,Zoltá...
# 3                                                NaN
# 4                                                NaN
#
#                                               Korean Mandarin Hebrew
# 0                                                NaN      NaN    NaN
# 1  Yun,MiNa;O,InSeong;Yang,JeongHwa;Lee,JiYeong;H...      NaN    NaN
# 2  Wu,JeongSin;Hong,SiHo;Yeo,MinJeong;Kim,SeoYeon...      NaN    NaN
# 3                                                NaN      NaN    NaN
# 4                                                NaN      NaN    NaN

# %%
# Merge
df = df.merge(newestdf, left_index= True, right_index= True, sort = False)

# %%
df.head()
# Out:
#                                           name  \
# 0                      Violet Evergarden Movie
# 1  Shingeki no Kyojin: The Final Season Part 2
# 2                           Kingdom 4th Season
# 3                                 Vinland Saga
# 4           Code Geass: Hangyaku no Lelouch R2
#
#                                            producers  ranking  votersCount  \
# 0  Aniplex;Dentsu;Shogakukan-ShueishaProductions;...        1       455691
# 1  Aniplex;SquareEnix;MainichiBroadcastingSystem;...        2      2139768
# 2  FrontierWorks;MediaFactory;KadokawaShoten;Movi...        3      1412369
# 3                             TVTokyo;Aniplex;Dentsu        4       253894
# 4  ProductionI.G;Dentsu;MainichiBroadcastingSyste...        5      1609418
#
#    score  popularity  members  favorite  episodes animeType premiredDate  \
# 0   9.35         235   811317     47477      28.0        TV     Fall2023
# 1   9.09           3  3378519    227339      64.0        TV   Spring2009
# 2   9.07          14  2587838    190464      24.0        TV   Spring2011
# 3   9.06         341   637587     16762      51.0        TV   Spring2015
# 4   9.05          21  2309721     59152      10.0        TV   Spring2019
#
#     animeSource                 genres              studios  \
# 0         Manga         Action;Fantasy             Madhouse
# 1         Manga   Action;Drama;Fantasy                Bones
# 2  Visual novel         Drama;Suspense             WhiteFox
# 3         Manga   Action;Comedy;Sci-Fi  BandaiNamcoPictures
# 4         Manga  Action;Drama;Suspense            WitStudio
#
#                       licenses                     rating  \
# 0                          NaN       PG-13-Teens13orolder
# 1  Funimation;AniplexofAmerica  R-17+(violence&profanity)
# 2                   Funimation       PG-13-Teens13orolder
# 3       Funimation;Crunchyroll       PG-13-Teens13orolder
# 4                   Funimation  R-17+(violence&profanity)
#
#                            voiceActorNameandlanguage  \
# 0  [['Ichinose,Kana', 'Japanese'], ['Harris,Jill'...
# 1  [['Kugimiya,Rie', 'Japanese'], ['Ponticelli,Be...
# 2  [['Seki,Tomokazu', 'Japanese'], ['Rinehart,Tys...
# 3  [['Kugimiya,Rie', 'Japanese'], ['Ishii,Kouji',...
# 4  [['Ishikawa,Yui', 'Japanese'], ['Perino,Elena'...
#
#                               staffNameandOccupation  \
# 0  [['Aoki,Haruka', 'Producer'], ['Fukushi,Yuuich...
# 1  [['Cook,Justin', 'Producer'], ['Maruyama,Hiroo...
# 2  [['Cook,Justin', 'Producer'], ['Danno,Yoshito'...
# 3  [['Miyawaki,Chizuru', 'Director,Storyboard,Key...
# 4  [['Cook,Justin', 'Producer'], ['Kinoshita,Tets...
#
#                                             Japanese  \
# 0  Ichinose,Kana;Tanezaki,Atsumi;Kobayashi,Chiaki...
# 1  Kugimiya,Rie;Park,Romi;Soumi,Youko;Kugimiya,Ri...
# 2  Seki,Tomokazu;Imai,Asami;Miyano,Mamoru;Hanazaw...
# 3  Kugimiya,Rie;Ishii,Kouji;Sugita,Tomokazu;Tomat...
# 4  Ishikawa,Yui;Inoue,Marina;Kamiya,Hiroshi;Kaji,...
#
#                                              English  \
# 0  Harris,Jill;Rodak,Mallorie;Cruz,JordanDash;Kar...
# 1  Whitehead,Maxey;Truncale,Lily;Mignogna,Vic;Hof...
# 2  Rinehart,Tyson;Nishimura,Trina;Tatum,J.Michael...
# 3  Loewen,Jocelyne;Daingerfield,Michael;Pitre,Sab...
# 4  Nishimura,Trina;Grelle,JessieJames;Mercer,Matt...
#
#                                               French  \
# 0  Thellier,Jehanne;Nonnenmacher,Marie;Lecordier,...
# 1  Pic,Audrey;Boudonnat,Lucille;Pestel,Arthur;Cré...
# 2  Pasquier,Laurent;Cornibert,Sarah;Wilhelm,Marc;...
# 3                                                NaN
# 4  Bienaimé,Nathalie;Niverd,Victor;Méyère,Bruno;B...
#
#                                       Portuguese(BR)  \
# 0  Rosis,MariaClara;Souza,Jacque;Miagusuku,Lucas;...
# 1  Andreatto,Rodrigo;Santana,Marina;Campos,Marcel...
# 2  Casemiro,Bruno;Cunha,Maitê;Rinaldi,André;Lua,B...
# 3                                                NaN
# 4  Stefane,Mayara;Volpato,Pedro;Sangregório,Bruno...
#
#                                              Italian  \
# 0  Marteddu,Agnese;Felli,Martina;Marteddu,Tito;Ru...
# 1  Ponticelli,Benedetta;Novara,Renato;Scianca,Pat...
# 2  Vivio,Paolo;Paolelli,Rachele;Chevalier,Davide;...
# 3  Granato,Jolanda;Fazio,Davide;Viola,Federico;Ma...
# 4  Perino,Elena;Bolognesi,Gaia;Raffaeli,Daniele;C...
#
#                                              Spanish  \
# 0  Estrada,Azucena;Ugalde,Erika;MartínezTorizes,E...
# 1  Torres,Jhonny;Vieira,JoséManuel;Escobar,Ricard...
# 2  Fernández,Iván;Vázquez,Camila;Naro,Jordi;Ramír...
# 3                                                NaN
# 4  Molina,Graciela;Lobo,Ana;Gómez,Marc;deAlba,Héc...
#
#                                               German  \
# 0  Fölster,Linda;Casper,Julia;Schächter,Janek;Vuc...
# 1  Gerick,Wanja;Turba,David;Häcke,Maximiliane;Mai...
# 2  Wirthgen,Jesco;Bäcker,Manuela;Gavrilis,Marios;...
# 3                                                NaN
# 4  Halm,Florian;Felder,Max;Gavrilis,Marios;Schwar...
#
#                                            Hungarian  \
# 0                                                NaN
# 1  Baráth,István;Szabó,Máté;Faragó,András;Varga,R...
# 2  Seszták,Szabolcs;NemesTakách,Kata;Juhász,Zoltá...
# 3                                                NaN
# 4                                                NaN
#
#                                               Korean Mandarin Hebrew
# 0                                                NaN      NaN    NaN
# 1  Yun,MiNa;O,InSeong;Yang,JeongHwa;Lee,JiYeong;H...      NaN    NaN
# 2  Wu,JeongSin;Hong,SiHo;Yeo,MinJeong;Kim,SeoYeon...      NaN    NaN
# 3                                                NaN      NaN    NaN
# 4                                                NaN      NaN    NaN

# %%
staffNnO = pd.DataFrame(df["staffNameandOccupation"])

# %%
# Limpeza dos dados
for index, data in enumerate(staffNnO["staffNameandOccupation"]):
    staffNnO["staffNameandOccupation"][index] = staffNnO["staffNameandOccupation"][index].replace("[[", "[")
    staffNnO["staffNameandOccupation"][index] = staffNnO["staffNameandOccupation"][index].replace("]]", "]")
    staffNnO["staffNameandOccupation"][index] = staffNnO["staffNameandOccupation"][index].replace("[\'", "")
    staffNnO["staffNameandOccupation"][index] = staffNnO["staffNameandOccupation"][index].replace("\'", "")
    staffNnO["staffNameandOccupation"][index] = staffNnO["staffNameandOccupation"][index].replace("], ", ";")
    staffNnO["staffNameandOccupation"][index] = staffNnO["staffNameandOccupation"][index].replace("]", "")

# %%
#Fazer split com base no indice
for index, data in enumerate(staffNnO["staffNameandOccupation"]):
    staffNnO["staffNameandOccupation"][index] = staffNnO["staffNameandOccupation"][index].split(";")
    for i, info in enumerate(staffNnO["staffNameandOccupation"][index]):
        staffNnO["staffNameandOccupation"][index][i] = staffNnO["staffNameandOccupation"][index][i].split(", ")

# %%
#Gera o dataframe
for i in range(len(staffNnO["staffNameandOccupation"])):
    for j, job in enumerate(staffNnO["staffNameandOccupation"][i]):
        if len(staffNnO["staffNameandOccupation"][i][j]) > 1:
            staffNnO["staffNameandOccupation"][i][j][-1] = staffNnO["staffNameandOccupation"][i][j][1].split(",")

# %%
staffNnO
# Out:
#                                 staffNameandOccupation
# 0    [[Aoki,Haruka, [Producer]], [Fukushi,Yuuichiro...
# 1    [[Cook,Justin, [Producer]], [Maruyama,Hiroo, [...
# 2    [[Cook,Justin, [Producer]], [Danno,Yoshito, [P...
# 3    [[Miyawaki,Chizuru, [Director, Storyboard, Key...
# 4    [[Cook,Justin, [Producer]], [Kinoshita,Tetsuya...
# ..                                                 ...
# 495  [[Kunisaki,Hisanori, [Producer]], [Maseba,Yuta...
# 496  [[Morihiro,Fumi, [Producer]], [Fujimaki,Tadato...
# 497  [[Hasegawa,Hiroya, [Producer]], [Iizuka,Toshio...
# 498  [[Nabeshima,Osamu, [Director]], [Honda,Yasuyuk...
# 499  [[Okada,Maiko, [Producer]], [Yamazaki,Takashi,...
#
# [500 rows x 1 columns]

# %%
# Fazer com que a profissão única seja usada em diferentes animes
unique_profes = []
for i in range(len(staffNnO["staffNameandOccupation"])):
    for j, job in enumerate(staffNnO["staffNameandOccupation"][i]):
        if len(job) > 1:
            for k, profes in enumerate(job[1]):
                if profes not in unique_profes:
                    unique_profes.append(profes)

# %%
unique_profes
# Out:
# ['Producer',
#  'Director',
#  'EpisodeDirector',
#  'Storyboard',
#  '2ndKeyAnimation',
#  'KeyAnimation',
#  'SoundDirector',
#  'AnimationDirector',
#  'In-BetweenAnimation',
#  'Script',
#  'SeriesComposition',
#  'ThemeSongArrangement',
#  'ThemeSongComposition',
#  'ThemeSongLyrics',
#  'Music',
#  'ThemeSongPerformance',
#  'InsertedSongPerformance',
#  'OriginalCharacterDesign',
#  'AssociateProducer',
#  'ExecutiveProducer',
#  'ChiefAnimationDirector',
#  'DirectorofPhotography',
#  'SpecialEffects',
#  'Planning',
#  'SoundEffects',
#  'AnimationCheck',
#  'Editing',
#  'AssistantAnimationDirector',
#  'ADRDirector',
#  'CharacterDesign',
#  'ColorDesign',
#  'BackgroundArt',
#  'ArtDirector',
#  'ChiefProducer',
#  'OriginalCreator',
#  'Publicity',
#  'DigitalPaint',
#  'ProductionCoordination',
#  'AssistantProducer',
#  'DialogueEditing',
#  'ColorSetting',
#  'AssistantDirector',
#  'Setting',
#  'RecordingEngineer',
#  'PlanningProducer',
#  'Screenplay',
#  'Layout',
#  'ProductionManager',
#  'ProductionAssistant',
#  'AssistantProductionCoordinat',
#  'CastingDirector',
#  'SoundSupervisor',
#  'SoundManager',
#  'Co-Director',
#  'SeriesProductionDirector',
#  'RecordingAssistant',
#  'Recording',
#  'PrincipleDrawing',
#  'MechanicalDesign',
#  'OnlineEditor',
#  'SettingManager',
#  'Creator',
#  'Co-Producer',
#  'Re-RecordingMixing',
#  'Spotting']

# %%
#Criando um dicionário de lista para que possamos transformá-lo em um dataframe mais tarde
profes_dic = dict()
for data in unique_profes:
    profes_dic[data] = []

# %%
profes_dic
# Out:
# {'Producer': [],
#  'Director': [],
#  'EpisodeDirector': [],
#  'Storyboard': [],
#  '2ndKeyAnimation': [],
#  'KeyAnimation': [],
#  'SoundDirector': [],
#  'AnimationDirector': [],
#  'In-BetweenAnimation': [],
#  'Script': [],
#  'SeriesComposition': [],
#  'ThemeSongArrangement': [],
#  'ThemeSongComposition': [],
#  'ThemeSongLyrics': [],
#  'Music': [],
#  'ThemeSongPerformance': [],
#  'InsertedSongPerformance': [],
#  'OriginalCharacterDesign': [],
#  'AssociateProducer': [],
#  'ExecutiveProducer': [],
#  'ChiefAnimationDirector': [],
#  'DirectorofPhotography': [],
#  'SpecialEffects': [],
#  'Planning': [],
#  'SoundEffects': [],
#  'AnimationCheck': [],
#  'Editing': [],
#  'AssistantAnimationDirector': [],
#  'ADRDirector': [],
#  'CharacterDesign': [],
#  'ColorDesign': [],
#  'BackgroundArt': [],
#  'ArtDirector': [],
#  'ChiefProducer': [],
#  'OriginalCreator': [],
#  'Publicity': [],
#  'DigitalPaint': [],
#  'ProductionCoordination': [],
#  'AssistantProducer': [],
#  'DialogueEditing': [],
#  'ColorSetting': [],
#  'AssistantDirector': [],
#  'Setting': [],
#  'RecordingEngineer': [],
#  'PlanningProducer': [],
#  'Screenplay': [],
#  'Layout': [],
#  'ProductionManager': [],
#  'ProductionAssistant': [],
#  'AssistantProductionCoordinat': [],
#  'CastingDirector': [],
#  'SoundSupervisor': [],
#  'SoundManager': [],
#  'Co-Director': [],
#  'SeriesProductionDirector': [],
#  'RecordingAssistant': [],
#  'Recording': [],
#  'PrincipleDrawing': [],
#  'MechanicalDesign': [],
#  'OnlineEditor': [],
#  'SettingManager': [],
#  'Creator': [],
#  'Co-Producer': [],
#  'Re-RecordingMixing': [],
#  'Spotting': []}

# %%
#Gerando o dataframe
for i in range(len(staffNnO["staffNameandOccupation"])):
    Producer = []
    Director = []
    EpisodeDirector = []
    Storyboard = []
    KeyAnimation2nd = []
    KeyAnimation = []
    SoundDirector = []
    AnimationDirector = []
    InBetweenAnimation = []
    Script = []
    SeriesComposition = []
    ThemeSongArrangement = []
    ThemeSongComposition = []
    ThemeSongLyrics = []
    Music = []
    ThemeSongPerformance = []
    InsertedSongPerformance = []
    OriginalCharacterDesign = []
    AssociateProducer = []
    ExecutiveProducer = []
    ChiefAnimationDirector = []
    DirectorofPhotography = []
    SpecialEffects = []
    Planning = []
    SoundEffects = []
    AnimationCheck = []
    Editing = []
    AssistantAnimationDirector = []
    ADRDirector = []
    CharacterDesign = []
    ColorDesign = []
    BackgroundArt = []
    ArtDirector = []
    ChiefProducer = []
    OriginalCreator = []
    Publicity = []
    DigitalPaint = []
    ProductionCoordination = []
    AssistantProducer = []
    DialogueEditing = []
    ColorSetting = []
    AssistantDirector = []
    Setting = []
    RecordingEngineer = []
    PlanningProducer = []
    Screenplay = []
    Layout = []
    ProductionManager = []
    ProductionAssistant = []
    AssistantProductionCoordinat = []
    CastingDirector = []
    SoundSupervisor = []
    SoundManager = []
    CoDirector = []
    SeriesProductionDirector = []
    RecordingAssistant = []
    Recording = []
    PrincipleDrawing = []
    MechanicalDesign = []
    OnlineEditor = []
    SettingManager = []
    Creator = []
    CoProducer = []
    ReRecordingMixing = []
    Spotting = []

    # Encontrando profissões únicas para que sejam nossas colunas
    for j, job in enumerate(staffNnO["staffNameandOccupation"][i]):
        if len(job) > 1:
            for k, profes in enumerate(job[1]):
                if profes == "Producer":
                    Producer.append(job[0])
                elif profes == "Director":
                    Director.append(job[0])
                elif profes == "EpisodeDirector":
                    EpisodeDirector.append(job[0])
                elif profes == "Storyboard":
                    Storyboard.append(job[0])
                elif profes == "KeyAnimation":
                    KeyAnimation.append(job[0])
                elif profes == "2ndKeyAnimation":
                    KeyAnimation2nd.append(job[0])
                elif profes == "SoundDirector":
                    SoundDirector.append(job[0])
                elif profes == "AnimationDirector":
                    AnimationDirector.append(job[0])
                elif profes == "In-BetweenAnimation":
                    InBetweenAnimation.append(job[0])
                elif profes == "Script":
                    Script.append(job[0])
                elif profes == "SeriesComposition":
                    SeriesComposition.append(job[0])
                elif profes == "ThemeSongArrangement":
                    ThemeSongArrangement.append(job[0])
                elif profes == "ThemeSongComposition":
                    ThemeSongComposition.append(job[0])
                elif profes == "ThemeSongLyrics":
                    ThemeSongLyrics.append(job[0])
                elif profes == "Music":
                    Music.append(job[0])
                elif profes == "ThemeSongPerformance":
                    ThemeSongPerformance.append(job[0])
                elif profes == "InsertedSongPerformance":
                    InsertedSongPerformance.append(job[0])
                elif profes == "OriginalCharacterDesign":
                    OriginalCharacterDesign.append(job[0])
                elif profes == "AssociateProducer":
                    AssociateProducer.append(job[0])
                elif profes == "ExecutiveProducer":
                    ExecutiveProducer.append(job[0])
                elif profes == "ChiefAnimationDirector":
                    ChiefAnimationDirector.append(job[0])
                elif profes == "DirectorofPhotography":
                    DirectorofPhotography.append(job[0])
                elif profes == "SpecialEffects":
                    SpecialEffects.append(job[0])
                elif profes == "Planning":
                    Planning.append(job[0])
                elif profes == "SoundEffects":
                    SoundEffects.append(job[0])
                elif profes == "AnimationCheck":
                    AnimationCheck.append(job[0])
                elif profes == "Editing":
                    Editing.append(job[0])
                elif profes == "AssistantAnimationDirector":
                    AssistantAnimationDirector.append(job[0])
                elif profes == "ADRDirector":
                    ADRDirector.append(job[0])
                elif profes == "CharacterDesign":
                    CharacterDesign.append(job[0])
                elif profes == "ColorDesign":
                    ColorDesign.append(job[0])
                elif profes == "BackgroundArt":
                    BackgroundArt.append(job[0])
                elif profes == "ArtDirector":
                    ArtDirector.append(job[0])
                elif profes == "ChiefProducer":
                    ChiefProducer.append(job[0])
                elif profes == "OriginalCreator":
                    OriginalCreator.append(job[0])
                elif profes == "Publicity":
                    Publicity.append(job[0])
                elif profes == "DigitalPaint":
                    DigitalPaint.append(job[0])
                elif profes == "ProductionCoordination":
                    ProductionCoordination.append(job[0])
                elif profes == "AssistantProducer":
                    AssistantProducer.append(job[0])
                elif profes == "DialogueEditing":
                    DialogueEditing.append(job[0])
                elif profes == "ColorSetting":
                    ColorSetting.append(job[0])
                elif profes == "AssistantDirector":
                    AssistantDirector.append(job[0])
                elif profes == "Setting":
                    Setting.append(job[0])
                elif profes == "RecordingEngineer":
                    RecordingEngineer.append(job[0])
                elif profes == "PlanningProducer":
                    PlanningProducer.append(job[0])
                elif profes == "Screenplay":
                    Screenplay.append(job[0])
                elif profes == "Layout":
                    Layout.append(job[0])
                elif profes == "ProductionManager":
                    ProductionManager.append(job[0])
                elif profes == "ProductionAssistant":
                    ProductionAssistant.append(job[0])
                elif profes == "AssistantProductionCoordinat":
                    AssistantProductionCoordinat.append(job[0])
                elif profes == "CastingDirector":
                    CastingDirector.append(job[0])
                elif profes == "SoundSupervisor":
                    SoundSupervisor.append(job[0])
                elif profes == "SoundManager":
                    SoundManager.append(job[0])
                elif profes == "Co-Director":
                    CoDirector.append(job[0])
                elif profes == "SeriesProductionDirector":
                    SeriesProductionDirector.append(job[0])
                elif profes == "RecordingAssistant":
                    RecordingAssistant.append(job[0])
                elif profes == "Recording":
                    Recording.append(job[0])
                elif profes == "PrincipleDrawing":
                    PrincipleDrawing.append(job[0])
                elif profes == "MechanicalDesign":
                    MechanicalDesign.append(job[0])
                elif profes == "OnlineEditor":
                    OnlineEditor.append(job[0])
                elif profes == "SettingManager":
                    SettingManager.append(job[0])
                elif profes == "Creator":
                    Creator.append(job[0])
                elif profes == "Co-Producer":
                    CoProducer.append(job[0])
                elif profes == "Re-RecordingMixing":
                    ReRecordingMixing.append(job[0])
                elif profes == "Spotting":
                    Spotting.append(job[0])

#Adiciona ao dicionário
profes_dic["Producer"].append(";".join(Producer))
profes_dic["Director"].append(";".join(Director))
profes_dic["EpisodeDirector"].append(";".join(EpisodeDirector))
profes_dic["Storyboard"].append(";".join(Storyboard))
profes_dic["KeyAnimation"].append(";".join(KeyAnimation))
profes_dic["2ndKeyAnimation"].append(";".join(KeyAnimation2nd))
profes_dic["SoundDirector"].append(";".join(SoundDirector))
profes_dic["AnimationDirector"].append(";".join(AnimationDirector))
profes_dic["In-BetweenAnimation"].append(";".join(InBetweenAnimation))
profes_dic["Script"].append(";".join(Script))
profes_dic["SeriesComposition"].append(";".join(SeriesComposition))
profes_dic["ThemeSongArrangement"].append(";".join(ThemeSongArrangement))
profes_dic["ThemeSongComposition"].append(";".join(ThemeSongComposition))
profes_dic["ThemeSongLyrics"].append(";".join(ThemeSongLyrics))
profes_dic["Music"].append(";".join(Music))
profes_dic["ThemeSongPerformance"].append(";".join(ThemeSongPerformance))
profes_dic["InsertedSongPerformance"].append(";".join(InsertedSongPerformance))
profes_dic["OriginalCharacterDesign"].append(";".join(OriginalCharacterDesign))
profes_dic["AssociateProducer"].append(";".join(AssociateProducer))
profes_dic["ExecutiveProducer"].append(";".join(ExecutiveProducer))
profes_dic["ChiefAnimationDirector"].append(";".join(ChiefAnimationDirector))
profes_dic["DirectorofPhotography"].append(";".join(DirectorofPhotography))
profes_dic["SpecialEffects"].append(";".join(SpecialEffects))
profes_dic["Planning"].append(";".join(Planning))
profes_dic["SoundEffects"].append(";".join(SoundEffects))
profes_dic["AnimationCheck"].append(";".join(AnimationCheck))
profes_dic["Editing"].append(";".join(Editing))
profes_dic["AssistantAnimationDirector"].append(";".join(AssistantAnimationDirector))
profes_dic["ADRDirector"].append(";".join(ADRDirector))
profes_dic["CharacterDesign"].append(";".join(CharacterDesign))
profes_dic["ColorDesign"].append(";".join(ColorDesign))
profes_dic["BackgroundArt"].append(";".join(BackgroundArt))
profes_dic["ArtDirector"].append(";".join(ArtDirector))
profes_dic["ChiefProducer"].append(";".join(ChiefProducer))
profes_dic["OriginalCreator"].append(";".join(OriginalCreator))
profes_dic["Publicity"].append(";".join(Publicity))
profes_dic["DigitalPaint"].append(";".join(DigitalPaint))
profes_dic["ProductionCoordination"].append(";".join(ProductionCoordination))
profes_dic["AssistantProducer"].append(";".join(AssistantProducer))
profes_dic["DialogueEditing"].append(";".join(DialogueEditing))
profes_dic["ColorSetting"].append(";".join(ColorSetting))
profes_dic["AssistantDirector"].append(";".join(AssistantDirector))
profes_dic["Setting"].append(";".join(Setting))
profes_dic["RecordingEngineer"].append(";".join(RecordingEngineer))
profes_dic["PlanningProducer"].append(";".join(PlanningProducer))
profes_dic["Screenplay"].append(";".join(Screenplay))
profes_dic["Layout"].append(";".join(Layout))
profes_dic["ProductionManager"].append(";".join(ProductionManager))
profes_dic["ProductionAssistant"].append(";".join(ProductionAssistant))
profes_dic["AssistantProductionCoordinat"].append(";".join(AssistantProductionCoordinat))
profes_dic["CastingDirector"].append(";".join(CastingDirector))
profes_dic["SoundSupervisor"].append(";".join(SoundSupervisor))
profes_dic["SoundManager"].append(";".join(SoundManager))
profes_dic["Co-Director"].append(";".join(CoDirector))
profes_dic["SeriesProductionDirector"].append(";".join(SeriesProductionDirector))
profes_dic["RecordingAssistant"].append(";".join(RecordingAssistant))
profes_dic["Recording"].append(";".join(Recording))
profes_dic["PrincipleDrawing"].append(";".join(PrincipleDrawing))
profes_dic["MechanicalDesign"].append(";".join(MechanicalDesign))
profes_dic["OnlineEditor"].append(";".join(OnlineEditor))
profes_dic["SettingManager"].append(";".join(SettingManager))
profes_dic["Creator"].append(";".join(Creator))
profes_dic["Co-Producer"].append(";".join(Co_Producer))
profes_dic["Re-RecordingMixing"].append(";".join(ReRecordingMixing))
profes_dic["Spotting"].append(";".join(Spotting))
